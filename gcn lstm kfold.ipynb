# %% [markdown]
# Labeled sequence of bitter peptides.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
import torch
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import scikitplot as skplt
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

from torch.nn import Linear
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, GATConv
from torch_geometric.nn import global_mean_pool, Set2Set

# %%
train_pos = pd.read_csv('train-positive.txt', header=None)
train_neg = pd.read_csv('train-negative.txt', header=None)
test_pos = pd.read_csv('test-positive.txt', header=None)
test_neg = pd.read_csv('test-negative.txt', header=None)

# %%
train_pos = pd.DataFrame([train_pos[::2].reset_index(drop=True)[0], train_pos[1::2].reset_index(drop=True)[0]]).T
train_neg = pd.DataFrame([train_neg[::2].reset_index(drop=True)[0], train_neg[1::2].reset_index(drop=True)[0]]).T
test_pos = pd.DataFrame([test_pos[::2].reset_index(drop=True)[0], test_pos[1::2].reset_index(drop=True)[0]]).T
test_neg = pd.DataFrame([test_neg[::2].reset_index(drop=True)[0], test_neg[1::2].reset_index(drop=True)[0]]).T

# %%
df = train_pos.append(train_neg).append(test_pos).append(test_neg).reset_index(drop=True)
df = df.sample(frac=1, random_state=911)
df
# Out:
#                  0           0
# 268   >Negative 12          GT
# 34    >Positive 34   VVVPPFLQP
# 173  >Positive 173       GGGLG
# 49    >Positive 49         YYG
# 288   >Negative 32  GHKIATFQER
# ..             ...         ...
# 580    >Negative 4     IPQEVLP
# 584    >Negative 8       ALPMH
# 95    >Positive 95          VL
# 283   >Negative 27       HQIYP
# 572   >Positive 60      RPFFGG
#
# [640 rows x 2 columns]

# %%
def create_graph_data(str, label, enc):
    n = len(str)
    edge_index_up = [[i, i+1] for i in range(n-1)]
    edge_index_down = [[i+1, i] for i in range(n-1)]
    edge_index = torch.tensor(edge_index_down + edge_index_up, dtype=torch.long)

    node_feats = enc.transform([[i] for i in str]).toarray()
    node_features = torch.tensor(node_feats, dtype=torch.float) 
    label = torch.tensor(label)
    d = Data(x = node_features, edge_index=edge_index.t().contiguous(), y = label)

    return(d)

def preprocess(df):
    df.iloc[:,0] = df.iloc[:,0].apply(lambda x: x.split(' ')[0][1:])
    df.columns = ['bitter', 'seq']
    labels = df.bitter.apply(lambda x: 1 if x=='Positive' else 0).tolist()
    seqs = df.seq.tolist()
    n = len(labels)
    descriptors = list(set([j for i in seqs for j in i]))
    enc = OneHotEncoder()
    X = np.array(descriptors).reshape((-1, 1))
    enc_arrays = enc.fit(X)

    protein_graphs = []
    for i in range(n):
        d = create_graph_data(seqs[i], labels[i], enc)
        protein_graphs.append(d)

    return(protein_graphs)

# %%
class gcnlstm(torch.nn.Module):
    def __init__(self, hidden_channels):
        super(gcnlstm, self).__init__()
        torch.manual_seed(12345)

        self.conv1 = GCNConv(20, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.conv3 = GCNConv(hidden_channels, hidden_channels)
        self.conv4 = GCNConv(hidden_channels, hidden_channels)
        self.conv5 = GCNConv(hidden_channels, hidden_channels)
        self.seqpool = Set2Set(hidden_channels, 1)
        self.lin = Linear(hidden_channels*2, 2)


    def forward(self, x, edge_index, batch):
        # 1. Obtain node embeddings 
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = self.conv2(x, edge_index)
        x = x.relu()
        x = self.conv3(x, edge_index)
        x = x.relu()
        x = self.conv4(x, edge_index)
        x = x.relu()
        x = self.conv5(x, edge_index)
        # 2. Readout layer
        x = self.seqpool(x, batch)  # [batch_size, hidden_channels]
        #x = global_mean_pool(x, batch)
        # 3. Apply a final classifier
        x = F.dropout(x, p=0.1, training=self.training)
        x = self.lin(x)
        
        return x

model = gcnlstm(hidden_channels=64)
print(model)
# Out:
# gcnlstm(
#   (conv1): GCNConv(20, 64)
#   (conv2): GCNConv(64, 64)
#   (conv3): GCNConv(64, 64)
#   (seqpool): Set2Set(64, 128)
#   (lin): Linear(in_features=128, out_features=2, bias=True)
# )

# %%
def train(model, optimizer, criterion):
    model.train()

    for data in train_loader:  # Iterate in batches over the training dataset.
         out = model(data.x, data.edge_index, data.batch)  # Perform a single forward pass.
         loss = criterion(out, data.y)  # Compute the loss.
         loss.backward()  # Derive gradients.
         optimizer.step()  # Update parameters based on gradients.
         optimizer.zero_grad()  # Clear gradients.
    return(model)
def test(loader, model):
     model.eval()

     correct = 0
     for data in loader:  # Iterate in batches over the training/test dataset.
         out = model(data.x, data.edge_index, data.batch)  
         pred = out.argmax(dim=1)  # Use the class with highest probability.
         correct += int((pred == data.y).sum())  # Check against ground-truth labels.
     return correct / len(loader.dataset)  # Derive ratio of correct predictions.

# %%
# k Fold
nsplits = 10
graph_data = preprocess(df)
n=len(graph_data)

fold_train_acc = []
fold_test_acc = []

# %%
graph_data[0], graph_data[7]
# Out:
# (Data(x=[2, 20], edge_index=[2, 2], y=0),
#  Data(x=[8, 20], edge_index=[2, 14], y=1))

# %%
for i in range(nsplits):    
    test_indexes = list(range(int(n*(i)/nsplits), int(n*(i+1)/nsplits)))
    train_indexes = [i for i in range(n) if i not in test_indexes]

    test_data = [graph_data[i] for i in test_indexes]
    train_data = [graph_data[i] for i in train_indexes]

    train_loader = DataLoader(train_data, batch_size=1, shuffle=True)
    test_loader = DataLoader(test_data, batch_size=64, shuffle = True) 

    model = gcnlstm(hidden_channels=16)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.005)
    criterion = torch.nn.CrossEntropyLoss()

    train_acc_list = []
    test_acc_list = []
    epochs_list = []

    for epoch in range(1, 30):
        model = train(model, optimizer, criterion)
        train_acc = test(train_loader, model)
        test_acc = test(test_loader, model)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)
        epochs_list.append(epoch)
        # print(f'Epoch: {epoch:03d}, Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}')
    
     
    print(f'Fold {i+1}:')
    print(f'Train size: {len(train_data)}, Test size: {len(test_data)}')
    print('Train Acc:', train_acc)
    print('Test Acc:', test_acc)
    
    fold_train_acc.append(train_acc)
    fold_test_acc.append(test_acc)

    fig, axs = plt.subplots(1,2, figsize=(10, 4))
    axs[0].plot(epochs_list, train_acc_list, label = 'train_acc')
    axs[0].plot(epochs_list, test_acc_list, label = 'test_acc')
    axs[0].legend()
    for data in test_loader:
        out = model(data.x, data.edge_index, data.batch)
        lab = data.y   
    skplt.metrics.plot_roc(lab, out.detach().numpy(), ax=axs[1])
    plt.show()
# Out:
# Fold 1:
# Train size: 576, Test size: 64
# Train Acc: 0.9409722222222222
# Test Acc: 0.84375
# Fold 2:
# Train size: 576, Test size: 64
# Train Acc: 0.9427083333333334
# Test Acc: 0.84375
# Fold 3:
# Train size: 576, Test size: 64
# Train Acc: 0.921875
# Test Acc: 0.875
# Fold 4:
# Train size: 576, Test size: 64
# Train Acc: 0.9565972222222222
# Test Acc: 0.8125
# Fold 5:
# Train size: 576, Test size: 64
# Train Acc: 0.9236111111111112
# Test Acc: 0.8125
# Fold 6:
# Train size: 576, Test size: 64
# Train Acc: 0.9427083333333334
# Test Acc: 0.828125
# Fold 7:
# Train size: 576, Test size: 64
# Train Acc: 0.8854166666666666
# Test Acc: 0.765625
# Fold 8:
# Train size: 576, Test size: 64
# Train Acc: 0.9305555555555556
# Test Acc: 0.890625
# Fold 9:
# Train size: 576, Test size: 64
# Train Acc: 0.9236111111111112
# Test Acc: 0.828125
# Fold 10:
# Train size: 576, Test size: 64
# Train Acc: 0.9288194444444444
# Test Acc: 0.734375
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16704/2110234280.py in <module>
#      19     for epoch in range(1, 30):
#      20         model = train(model, optimizer, criterion)
# ---> 21         train_acc = test(train_loader, model)
#      22         test_acc = test(test_loader, model)
#      23         train_acc_list.append(train_acc)
#
# ~\AppData\Local\Temp/ipykernel_16704/3154137738.py in test(loader, model)
#      14      correct = 0
#      15      for data in loader:  # Iterate in batches over the training/test dataset.
# ---> 16          out = model(data.x, data.edge_index, data.batch)
#      17          pred = out.argmax(dim=1)  # Use the class with highest probability.
#      18          correct += int((pred == data.y).sum())  # Check against ground-truth labels.
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\AppData\Local\Temp/ipykernel_16704/453971910.py in forward(self, x, edge_index, batch)
#      17         x = self.conv2(x, edge_index)
#      18         x = x.relu()
# ---> 19         x = self.conv3(x, edge_index)
#      20         x = x.relu()
#      21         # 2. Readout layer
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch_geometric\nn\conv\gcn_conv.py in forward(self, x, edge_index, edge_weight)
#     170                 cache = self._cached_edge_index
#     171                 if cache is None:
# --> 172                     edge_index, edge_weight = gcn_norm(  # yapf: disable
#     173                         edge_index, edge_weight, x.size(self.node_dim),
#     174                         self.improved, self.add_self_loops)
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch_geometric\nn\conv\gcn_conv.py in gcn_norm(edge_index, edge_weight, num_nodes, improved, add_self_loops, dtype)
#      56
#      57         if add_self_loops:
# ---> 58             edge_index, tmp_edge_weight = add_remaining_self_loops(
#      59                 edge_index, edge_weight, fill_value, num_nodes)
#      60             assert tmp_edge_weight is not None
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch_geometric\utils\loop.py in add_remaining_self_loops(edge_index, edge_attr, fill_value, num_nodes)
#     206
#     207         elif isinstance(fill_value, (int, float)):
# --> 208             loop_attr = edge_attr.new_full((N, ) + edge_attr.size()[1:],
#     209                                            fill_value)
#     210         elif isinstance(fill_value, Tensor):
#
# KeyboardInterrupt:

# %%
np.mean(fold_test_acc)
# Out:
# 0.8234375
