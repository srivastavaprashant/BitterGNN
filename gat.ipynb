# %%
import pandas as pd
import numpy as np

# %%
import torch
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import scikitplot as skplt

from torch.nn import Linear
import torch.nn.functional as F
from torch_geometric.nn import GATConv
from torch_geometric.nn import global_mean_pool

# %%
train_pos = pd.read_csv('train-positive.txt', header=None)
train_neg = pd.read_csv('train-negative.txt', header=None)
test_pos = pd.read_csv('test-positive.txt', header=None)
test_neg = pd.read_csv('test-negative.txt', header=None)

# %%
train_pos = pd.DataFrame([train_pos[::2].reset_index(drop=True)[0], train_pos[1::2].reset_index(drop=True)[0]]).T
train_neg = pd.DataFrame([train_neg[::2].reset_index(drop=True)[0], train_neg[1::2].reset_index(drop=True)[0]]).T
test_pos = pd.DataFrame([test_pos[::2].reset_index(drop=True)[0], test_pos[1::2].reset_index(drop=True)[0]]).T
test_neg = pd.DataFrame([test_neg[::2].reset_index(drop=True)[0], test_neg[1::2].reset_index(drop=True)[0]]).T

# %%
df = test_neg.append(test_pos).append(train_pos).append(train_neg).reset_index(drop=True)
df.iloc[:,0] = df.iloc[:,0].apply(lambda x: x.split(' ')[0][1:])
df.columns = ['bitter', 'seq']
df
# Out:
#        bitter               seq
# 0    Negative                AA
# 1    Negative               IKP
# 2    Negative               ILP
# 3    Negative          PFFDPQIP
# 4    Negative           IPQEVLP
# ..        ...               ...
# 635  Negative          NPPHQIYP
# 636  Negative              AIYK
# 637  Negative  ENGLPVHLDQSIFRRP
# 638  Negative             AMKPW
# 639  Negative           GYALPHA
#
# [640 rows x 2 columns]

# %%
df = df.sample(frac=1)

# %%
df = df.sample(frac=1)
labels = df.bitter.apply(lambda x: 1 if x=='Positive' else 0).values
seq = df.seq.values

# %%
descriptors = list(set([j for i in seq for j in i]))
enc = OneHotEncoder()
X = np.array(descriptors).reshape((-1, 1))
enc_arrays = enc.fit(X)

# %%
def create_graph_data(str, label):
    n = len(str)
    edge_index_up = [[i, i+1] for i in range(n-1)]
    edge_index_down = [[i+1, i] for i in range(n-1)]
    edge_index = torch.tensor(edge_index_down + edge_index_up, dtype=torch.long)

    node_feats = enc.transform([[i] for i in str]).toarray()
    node_features = torch.tensor(node_feats, dtype=torch.float) 
    label = torch.tensor(label)
    d = Data(x = node_features, edge_index=edge_index.t().contiguous(), y = label)

    return(d)

# %%
data_list = []

# %%
for i in range(len(labels)):
    d = create_graph_data(seq[i], labels[i])

    data_list.append(d)

# %%
train_data, test_data = train_test_split(data_list, test_size=0.1)

# %%
train_loader = DataLoader(train_data, batch_size=64)
test_loader = DataLoader(test_data, batch_size=64)

# %%
for step, data in enumerate(train_loader):
    print(f'Step {step + 1}:')
    print('=======')
    print(f'Number of graphs in the current batch: {data.num_graphs}')
    print(data)
    print()
# Out:
# Step 1:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[351, 20], edge_index=[2, 574], y=[64], batch=[351], ptr=[65])
#
# Step 2:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[301, 20], edge_index=[2, 474], y=[64], batch=[301], ptr=[65])
#
# Step 3:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[351, 20], edge_index=[2, 574], y=[64], batch=[351], ptr=[65])
#
# Step 4:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[358, 20], edge_index=[2, 588], y=[64], batch=[358], ptr=[65])
#
# Step 5:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[309, 20], edge_index=[2, 490], y=[64], batch=[309], ptr=[65])
#
# Step 6:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[363, 20], edge_index=[2, 598], y=[64], batch=[363], ptr=[65])
#
# Step 7:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[312, 20], edge_index=[2, 496], y=[64], batch=[312], ptr=[65])
#
# Step 8:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[327, 20], edge_index=[2, 526], y=[64], batch=[327], ptr=[65])
#
# Step 9:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[343, 20], edge_index=[2, 558], y=[64], batch=[343], ptr=[65])

# %%
class GATconv(torch.nn.Module):
    def __init__(self, hidden_channels):
        super(GATconv, self).__init__()
        torch.manual_seed(12345)
        self.conv1 = GATConv(20, hidden_channels)
        self.conv2 = GATConv(hidden_channels, hidden_channels)
        self.conv3 = GATConv(hidden_channels, hidden_channels)
        self.lin = Linear(hidden_channels, 2)

    def forward(self, x, edge_index, batch):
        # 1. Obtain node embeddings 
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = self.conv2(x, edge_index)
        x = x.relu()
        #x = F.dropout(x, p = 0.1, training=self.training)
        x = self.conv3(x, edge_index)

        # 2. Readout layer
        x = global_mean_pool(x, batch)  # [batch_size, hidden_channels]

        # 3. Apply a final classifier
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin(x)
        
        return x

model = GATconv(hidden_channels=64)
print(model)
# Out:
# GATconv(
#   (conv1): GATConv(20, 64, heads=1)
#   (conv2): GATConv(64, 64, heads=1)
#   (conv3): GATConv(64, 64, heads=1)
#   (lin): Linear(in_features=64, out_features=2, bias=True)
# )

# %%
model = GATconv(hidden_channels=16)
optimizer = torch.optim.Adam(model.parameters(), lr=0.0005)
criterion = torch.nn.CrossEntropyLoss()

def train():
    model.train()

    for data in train_loader:  # Iterate in batches over the training dataset.
         out = model(data.x, data.edge_index, data.batch)  # Perform a single forward pass.
         loss = criterion(out, data.y)  # Compute the loss.
         loss.backward()  # Derive gradients.
         optimizer.step()  # Update parameters based on gradients.
         optimizer.zero_grad()  # Clear gradients.

def test(loader):
     model.eval()

     correct = 0
     for data in loader:  # Iterate in batches over the training/test dataset.
         out = model(data.x, data.edge_index, data.batch)  
         pred = out.argmax(dim=1)  # Use the class with highest probability.
         correct += int((pred == data.y).sum())  # Check against ground-truth labels.
     return correct / len(loader.dataset)  # Derive ratio of correct predictions.


for epoch in range(1, 700):
    train()
    train_acc = test(train_loader)
    test_acc = test(test_loader)
    print(f'Epoch: {epoch:03d}, Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}')
# Out:
# Epoch: 001, Train Acc: 0.5035, Test Acc: 0.4844
# Epoch: 002, Train Acc: 0.5017, Test Acc: 0.4844
# Epoch: 003, Train Acc: 0.4983, Test Acc: 0.5000
# Epoch: 004, Train Acc: 0.5226, Test Acc: 0.5000
# Epoch: 005, Train Acc: 0.5417, Test Acc: 0.5312
# Epoch: 006, Train Acc: 0.5764, Test Acc: 0.5625
# Epoch: 007, Train Acc: 0.6146, Test Acc: 0.6094
# Epoch: 008, Train Acc: 0.6562, Test Acc: 0.6875
# Epoch: 009, Train Acc: 0.6875, Test Acc: 0.7344
# Epoch: 010, Train Acc: 0.7222, Test Acc: 0.7500
# Epoch: 011, Train Acc: 0.7240, Test Acc: 0.7500
# Epoch: 012, Train Acc: 0.7396, Test Acc: 0.7188
# Epoch: 013, Train Acc: 0.7413, Test Acc: 0.7188
# Epoch: 014, Train Acc: 0.7431, Test Acc: 0.7500
# Epoch: 015, Train Acc: 0.7500, Test Acc: 0.7656
# Epoch: 016, Train Acc: 0.7552, Test Acc: 0.7656
# Epoch: 017, Train Acc: 0.7517, Test Acc: 0.7656
# Epoch: 018, Train Acc: 0.7517, Test Acc: 0.7656
# Epoch: 019, Train Acc: 0.7569, Test Acc: 0.7656
# Epoch: 020, Train Acc: 0.7535, Test Acc: 0.7656
# Epoch: 021, Train Acc: 0.7587, Test Acc: 0.7656
# Epoch: 022, Train Acc: 0.7552, Test Acc: 0.7812
# Epoch: 023, Train Acc: 0.7639, Test Acc: 0.7969
# Epoch: 024, Train Acc: 0.7708, Test Acc: 0.7969
# Epoch: 025, Train Acc: 0.7743, Test Acc: 0.7969
# Epoch: 026, Train Acc: 0.7795, Test Acc: 0.7656
# Epoch: 027, Train Acc: 0.7778, Test Acc: 0.7656
# Epoch: 028, Train Acc: 0.7830, Test Acc: 0.7656
# Epoch: 029, Train Acc: 0.7865, Test Acc: 0.7656
# Epoch: 030, Train Acc: 0.7830, Test Acc: 0.7812
# Epoch: 031, Train Acc: 0.7847, Test Acc: 0.7656
# Epoch: 032, Train Acc: 0.7882, Test Acc: 0.7500
# Epoch: 033, Train Acc: 0.7986, Test Acc: 0.7656
# Epoch: 034, Train Acc: 0.7951, Test Acc: 0.7656
# Epoch: 035, Train Acc: 0.8038, Test Acc: 0.7500
# Epoch: 036, Train Acc: 0.8108, Test Acc: 0.7500
# Epoch: 037, Train Acc: 0.8073, Test Acc: 0.7656
# Epoch: 038, Train Acc: 0.8021, Test Acc: 0.7656
# Epoch: 039, Train Acc: 0.8108, Test Acc: 0.7656
# Epoch: 040, Train Acc: 0.8108, Test Acc: 0.7656
# Epoch: 041, Train Acc: 0.8108, Test Acc: 0.7656
# Epoch: 042, Train Acc: 0.8160, Test Acc: 0.7656
# Epoch: 043, Train Acc: 0.8160, Test Acc: 0.7812
# Epoch: 044, Train Acc: 0.8177, Test Acc: 0.7969
# Epoch: 045, Train Acc: 0.8194, Test Acc: 0.7969
# Epoch: 046, Train Acc: 0.8212, Test Acc: 0.7969
# Epoch: 047, Train Acc: 0.8212, Test Acc: 0.7969
# Epoch: 048, Train Acc: 0.8194, Test Acc: 0.7969
# Epoch: 049, Train Acc: 0.8212, Test Acc: 0.7969
# Epoch: 050, Train Acc: 0.8247, Test Acc: 0.7969
# Epoch: 051, Train Acc: 0.8247, Test Acc: 0.7812
# Epoch: 052, Train Acc: 0.8264, Test Acc: 0.7812
# Epoch: 053, Train Acc: 0.8299, Test Acc: 0.7812
# Epoch: 054, Train Acc: 0.8299, Test Acc: 0.7812
# Epoch: 055, Train Acc: 0.8299, Test Acc: 0.7812
# Epoch: 056, Train Acc: 0.8299, Test Acc: 0.7812
# Epoch: 057, Train Acc: 0.8299, Test Acc: 0.7812
# Epoch: 058, Train Acc: 0.8281, Test Acc: 0.7656
# Epoch: 059, Train Acc: 0.8316, Test Acc: 0.7812
# Epoch: 060, Train Acc: 0.8316, Test Acc: 0.7812
# Epoch: 061, Train Acc: 0.8333, Test Acc: 0.7656
# Epoch: 062, Train Acc: 0.8333, Test Acc: 0.7656
# Epoch: 063, Train Acc: 0.8333, Test Acc: 0.7969
# Epoch: 064, Train Acc: 0.8333, Test Acc: 0.7969
# Epoch: 065, Train Acc: 0.8368, Test Acc: 0.7812
# Epoch: 066, Train Acc: 0.8351, Test Acc: 0.7969
# Epoch: 067, Train Acc: 0.8368, Test Acc: 0.7969
# Epoch: 068, Train Acc: 0.8368, Test Acc: 0.7969
# Epoch: 069, Train Acc: 0.8385, Test Acc: 0.7969
# Epoch: 070, Train Acc: 0.8438, Test Acc: 0.7969
# Epoch: 071, Train Acc: 0.8438, Test Acc: 0.7969
# Epoch: 072, Train Acc: 0.8438, Test Acc: 0.7969
# Epoch: 073, Train Acc: 0.8455, Test Acc: 0.7969
# Epoch: 074, Train Acc: 0.8455, Test Acc: 0.7969
# Epoch: 075, Train Acc: 0.8472, Test Acc: 0.7969
# Epoch: 076, Train Acc: 0.8455, Test Acc: 0.7969
# Epoch: 077, Train Acc: 0.8490, Test Acc: 0.7969
# Epoch: 078, Train Acc: 0.8490, Test Acc: 0.7969
# Epoch: 079, Train Acc: 0.8507, Test Acc: 0.7969
# Epoch: 080, Train Acc: 0.8542, Test Acc: 0.7969
# Epoch: 081, Train Acc: 0.8542, Test Acc: 0.7969
# Epoch: 082, Train Acc: 0.8524, Test Acc: 0.7969
# Epoch: 083, Train Acc: 0.8524, Test Acc: 0.7969
# Epoch: 084, Train Acc: 0.8559, Test Acc: 0.7969
# Epoch: 085, Train Acc: 0.8542, Test Acc: 0.7969
# Epoch: 086, Train Acc: 0.8576, Test Acc: 0.7969
# Epoch: 087, Train Acc: 0.8594, Test Acc: 0.7969
# Epoch: 088, Train Acc: 0.8611, Test Acc: 0.7969
# Epoch: 089, Train Acc: 0.8611, Test Acc: 0.7969
# Epoch: 090, Train Acc: 0.8611, Test Acc: 0.7969
# Epoch: 091, Train Acc: 0.8628, Test Acc: 0.7812
# Epoch: 092, Train Acc: 0.8628, Test Acc: 0.7812
# Epoch: 093, Train Acc: 0.8628, Test Acc: 0.7812
# Epoch: 094, Train Acc: 0.8611, Test Acc: 0.7812
# Epoch: 095, Train Acc: 0.8594, Test Acc: 0.7812
# Epoch: 096, Train Acc: 0.8611, Test Acc: 0.7812
# Epoch: 097, Train Acc: 0.8611, Test Acc: 0.7812
# Epoch: 098, Train Acc: 0.8611, Test Acc: 0.7812
# Epoch: 099, Train Acc: 0.8646, Test Acc: 0.7969
# Epoch: 100, Train Acc: 0.8646, Test Acc: 0.8125
# Epoch: 101, Train Acc: 0.8646, Test Acc: 0.8125
# Epoch: 102, Train Acc: 0.8646, Test Acc: 0.8125
# Epoch: 103, Train Acc: 0.8663, Test Acc: 0.8125
# Epoch: 104, Train Acc: 0.8646, Test Acc: 0.8125
# Epoch: 105, Train Acc: 0.8663, Test Acc: 0.8125
# Epoch: 106, Train Acc: 0.8663, Test Acc: 0.8281
# Epoch: 107, Train Acc: 0.8663, Test Acc: 0.8125
# Epoch: 108, Train Acc: 0.8698, Test Acc: 0.8125
# Epoch: 109, Train Acc: 0.8681, Test Acc: 0.8125
# Epoch: 110, Train Acc: 0.8681, Test Acc: 0.8125
# Epoch: 111, Train Acc: 0.8698, Test Acc: 0.8281
# Epoch: 112, Train Acc: 0.8698, Test Acc: 0.8125
# Epoch: 113, Train Acc: 0.8698, Test Acc: 0.8125
# Epoch: 114, Train Acc: 0.8715, Test Acc: 0.8281
# Epoch: 115, Train Acc: 0.8715, Test Acc: 0.8281
# Epoch: 116, Train Acc: 0.8698, Test Acc: 0.8125
# Epoch: 117, Train Acc: 0.8698, Test Acc: 0.8125
# Epoch: 118, Train Acc: 0.8715, Test Acc: 0.8281
# Epoch: 119, Train Acc: 0.8733, Test Acc: 0.8125
# Epoch: 120, Train Acc: 0.8733, Test Acc: 0.8281
# Epoch: 121, Train Acc: 0.8733, Test Acc: 0.8281
# Epoch: 122, Train Acc: 0.8733, Test Acc: 0.8281
# Epoch: 123, Train Acc: 0.8733, Test Acc: 0.8281
# Epoch: 124, Train Acc: 0.8750, Test Acc: 0.8438
# Epoch: 125, Train Acc: 0.8767, Test Acc: 0.8438
# Epoch: 126, Train Acc: 0.8767, Test Acc: 0.8438
# Epoch: 127, Train Acc: 0.8767, Test Acc: 0.8438
# Epoch: 128, Train Acc: 0.8750, Test Acc: 0.8438
# Epoch: 129, Train Acc: 0.8715, Test Acc: 0.8438
# Epoch: 130, Train Acc: 0.8715, Test Acc: 0.8438
# Epoch: 131, Train Acc: 0.8750, Test Acc: 0.8438
# Epoch: 132, Train Acc: 0.8750, Test Acc: 0.8438
# Epoch: 133, Train Acc: 0.8750, Test Acc: 0.8438
# Epoch: 134, Train Acc: 0.8750, Test Acc: 0.8438
# Epoch: 135, Train Acc: 0.8785, Test Acc: 0.8594
# Epoch: 136, Train Acc: 0.8767, Test Acc: 0.8438
# Epoch: 137, Train Acc: 0.8750, Test Acc: 0.8438
# Epoch: 138, Train Acc: 0.8819, Test Acc: 0.8594
# Epoch: 139, Train Acc: 0.8837, Test Acc: 0.8594
# Epoch: 140, Train Acc: 0.8785, Test Acc: 0.8594
# Epoch: 141, Train Acc: 0.8785, Test Acc: 0.8594
# Epoch: 142, Train Acc: 0.8802, Test Acc: 0.8594
# Epoch: 143, Train Acc: 0.8819, Test Acc: 0.8750
# Epoch: 144, Train Acc: 0.8819, Test Acc: 0.8750
# Epoch: 145, Train Acc: 0.8854, Test Acc: 0.8750
# Epoch: 146, Train Acc: 0.8819, Test Acc: 0.8750
# Epoch: 147, Train Acc: 0.8819, Test Acc: 0.8594
# Epoch: 148, Train Acc: 0.8819, Test Acc: 0.8594
# Epoch: 149, Train Acc: 0.8819, Test Acc: 0.8594
# Epoch: 150, Train Acc: 0.8819, Test Acc: 0.8594
# Epoch: 151, Train Acc: 0.8837, Test Acc: 0.8750
# Epoch: 152, Train Acc: 0.8854, Test Acc: 0.8750
# Epoch: 153, Train Acc: 0.8872, Test Acc: 0.8750
# Epoch: 154, Train Acc: 0.8837, Test Acc: 0.8750
# Epoch: 155, Train Acc: 0.8872, Test Acc: 0.8906
# Epoch: 156, Train Acc: 0.8889, Test Acc: 0.8750
# Epoch: 157, Train Acc: 0.8889, Test Acc: 0.8750
# Epoch: 158, Train Acc: 0.8906, Test Acc: 0.8906
# Epoch: 159, Train Acc: 0.8889, Test Acc: 0.8750
# Epoch: 160, Train Acc: 0.8906, Test Acc: 0.8750
# Epoch: 161, Train Acc: 0.8924, Test Acc: 0.8906
# Epoch: 162, Train Acc: 0.8941, Test Acc: 0.8906
# Epoch: 163, Train Acc: 0.8958, Test Acc: 0.8906
# Epoch: 164, Train Acc: 0.8941, Test Acc: 0.8906
# Epoch: 165, Train Acc: 0.8941, Test Acc: 0.8906
# Epoch: 166, Train Acc: 0.8941, Test Acc: 0.8906
# Epoch: 167, Train Acc: 0.8958, Test Acc: 0.8906
# Epoch: 168, Train Acc: 0.8976, Test Acc: 0.8906
# Epoch: 169, Train Acc: 0.8976, Test Acc: 0.8906
# Epoch: 170, Train Acc: 0.8941, Test Acc: 0.8906
# Epoch: 171, Train Acc: 0.8993, Test Acc: 0.8750
# Epoch: 172, Train Acc: 0.8976, Test Acc: 0.8750
# Epoch: 173, Train Acc: 0.8958, Test Acc: 0.8750
# Epoch: 174, Train Acc: 0.8976, Test Acc: 0.8750
# Epoch: 175, Train Acc: 0.9010, Test Acc: 0.8750
# Epoch: 176, Train Acc: 0.9045, Test Acc: 0.8594
# Epoch: 177, Train Acc: 0.9045, Test Acc: 0.8750
# Epoch: 178, Train Acc: 0.8993, Test Acc: 0.8750
# Epoch: 179, Train Acc: 0.9028, Test Acc: 0.8594
# Epoch: 180, Train Acc: 0.9045, Test Acc: 0.8750
# Epoch: 181, Train Acc: 0.9045, Test Acc: 0.8750
# Epoch: 182, Train Acc: 0.9045, Test Acc: 0.8594
# Epoch: 183, Train Acc: 0.9045, Test Acc: 0.8594
# Epoch: 184, Train Acc: 0.9045, Test Acc: 0.8594
# Epoch: 185, Train Acc: 0.9080, Test Acc: 0.8750
# Epoch: 186, Train Acc: 0.9080, Test Acc: 0.8750
# Epoch: 187, Train Acc: 0.9062, Test Acc: 0.8594
# Epoch: 188, Train Acc: 0.9045, Test Acc: 0.8594
# Epoch: 189, Train Acc: 0.9062, Test Acc: 0.8594
# Epoch: 190, Train Acc: 0.9062, Test Acc: 0.8594
# Epoch: 191, Train Acc: 0.9080, Test Acc: 0.8750
# Epoch: 192, Train Acc: 0.9062, Test Acc: 0.8750
# Epoch: 193, Train Acc: 0.9080, Test Acc: 0.8750
# Epoch: 194, Train Acc: 0.9080, Test Acc: 0.8750
# Epoch: 195, Train Acc: 0.9080, Test Acc: 0.8594
# Epoch: 196, Train Acc: 0.9080, Test Acc: 0.8750
# Epoch: 197, Train Acc: 0.9080, Test Acc: 0.8750
# Epoch: 198, Train Acc: 0.9097, Test Acc: 0.8750
# Epoch: 199, Train Acc: 0.9097, Test Acc: 0.8594
# Epoch: 200, Train Acc: 0.9080, Test Acc: 0.8750
# Epoch: 201, Train Acc: 0.9080, Test Acc: 0.8594
# Epoch: 202, Train Acc: 0.9080, Test Acc: 0.8594
# Epoch: 203, Train Acc: 0.9097, Test Acc: 0.8594
# Epoch: 204, Train Acc: 0.9080, Test Acc: 0.8438
# Epoch: 205, Train Acc: 0.9097, Test Acc: 0.8594
# Epoch: 206, Train Acc: 0.9097, Test Acc: 0.8594
# Epoch: 207, Train Acc: 0.9097, Test Acc: 0.8594
# Epoch: 208, Train Acc: 0.9097, Test Acc: 0.8594
# Epoch: 209, Train Acc: 0.9062, Test Acc: 0.8438
# Epoch: 210, Train Acc: 0.9080, Test Acc: 0.8438
# Epoch: 211, Train Acc: 0.9080, Test Acc: 0.8438
# Epoch: 212, Train Acc: 0.9115, Test Acc: 0.8594
# Epoch: 213, Train Acc: 0.9132, Test Acc: 0.8594
# Epoch: 214, Train Acc: 0.9132, Test Acc: 0.8594
# Epoch: 215, Train Acc: 0.9149, Test Acc: 0.8594
# Epoch: 216, Train Acc: 0.9132, Test Acc: 0.8594
# Epoch: 217, Train Acc: 0.9149, Test Acc: 0.8594
# Epoch: 218, Train Acc: 0.9149, Test Acc: 0.8594
# Epoch: 219, Train Acc: 0.9167, Test Acc: 0.8594
# Epoch: 220, Train Acc: 0.9167, Test Acc: 0.8594
# Epoch: 221, Train Acc: 0.9115, Test Acc: 0.8594
# Epoch: 222, Train Acc: 0.9132, Test Acc: 0.8594
# Epoch: 223, Train Acc: 0.9149, Test Acc: 0.8594
# Epoch: 224, Train Acc: 0.9149, Test Acc: 0.8594
# Epoch: 225, Train Acc: 0.9149, Test Acc: 0.8594
# Epoch: 226, Train Acc: 0.9149, Test Acc: 0.8594
# Epoch: 227, Train Acc: 0.9149, Test Acc: 0.8594
# Epoch: 228, Train Acc: 0.9132, Test Acc: 0.8438
# Epoch: 229, Train Acc: 0.9132, Test Acc: 0.8438
# Epoch: 230, Train Acc: 0.9132, Test Acc: 0.8438
# Epoch: 231, Train Acc: 0.9132, Test Acc: 0.8281
# Epoch: 232, Train Acc: 0.9115, Test Acc: 0.8438
# Epoch: 233, Train Acc: 0.9132, Test Acc: 0.8594
# Epoch: 234, Train Acc: 0.9132, Test Acc: 0.8438
# Epoch: 235, Train Acc: 0.9132, Test Acc: 0.8281
# Epoch: 236, Train Acc: 0.9149, Test Acc: 0.8594
# Epoch: 237, Train Acc: 0.9167, Test Acc: 0.8594
# Epoch: 238, Train Acc: 0.9132, Test Acc: 0.8438
# Epoch: 239, Train Acc: 0.9132, Test Acc: 0.8438
# Epoch: 240, Train Acc: 0.9132, Test Acc: 0.8594
# Epoch: 241, Train Acc: 0.9115, Test Acc: 0.8594
# Epoch: 242, Train Acc: 0.9115, Test Acc: 0.8594
# Epoch: 243, Train Acc: 0.9115, Test Acc: 0.8594
# Epoch: 244, Train Acc: 0.9132, Test Acc: 0.8594
# Epoch: 245, Train Acc: 0.9132, Test Acc: 0.8438
# Epoch: 246, Train Acc: 0.9132, Test Acc: 0.8594
# Epoch: 247, Train Acc: 0.9132, Test Acc: 0.8438
# Epoch: 248, Train Acc: 0.9149, Test Acc: 0.8281
# Epoch: 249, Train Acc: 0.9132, Test Acc: 0.8438
# Epoch: 250, Train Acc: 0.9149, Test Acc: 0.8594
# Epoch: 251, Train Acc: 0.9115, Test Acc: 0.8594
# Epoch: 252, Train Acc: 0.9115, Test Acc: 0.8594
# Epoch: 253, Train Acc: 0.9115, Test Acc: 0.8594
# Epoch: 254, Train Acc: 0.9132, Test Acc: 0.8438
# Epoch: 255, Train Acc: 0.9167, Test Acc: 0.8594
# Epoch: 256, Train Acc: 0.9149, Test Acc: 0.8594
# Epoch: 257, Train Acc: 0.9132, Test Acc: 0.8438
# Epoch: 258, Train Acc: 0.9132, Test Acc: 0.8438
# Epoch: 259, Train Acc: 0.9149, Test Acc: 0.8438
# Epoch: 260, Train Acc: 0.9115, Test Acc: 0.8438
# Epoch: 261, Train Acc: 0.9115, Test Acc: 0.8438
# Epoch: 262, Train Acc: 0.9132, Test Acc: 0.8438
# Epoch: 263, Train Acc: 0.9132, Test Acc: 0.8438
# Epoch: 264, Train Acc: 0.9184, Test Acc: 0.8438
# Epoch: 265, Train Acc: 0.9149, Test Acc: 0.8438
# Epoch: 266, Train Acc: 0.9149, Test Acc: 0.8594
# Epoch: 267, Train Acc: 0.9167, Test Acc: 0.8438
# Epoch: 268, Train Acc: 0.9219, Test Acc: 0.8594
# Epoch: 269, Train Acc: 0.9201, Test Acc: 0.8438
# Epoch: 270, Train Acc: 0.9132, Test Acc: 0.8438
# Epoch: 271, Train Acc: 0.9149, Test Acc: 0.8438
# Epoch: 272, Train Acc: 0.9184, Test Acc: 0.8438
# Epoch: 273, Train Acc: 0.9149, Test Acc: 0.8438
# Epoch: 274, Train Acc: 0.9149, Test Acc: 0.8438
# Epoch: 275, Train Acc: 0.9149, Test Acc: 0.8438
# Epoch: 276, Train Acc: 0.9149, Test Acc: 0.8438
# Epoch: 277, Train Acc: 0.9149, Test Acc: 0.8438
# Epoch: 278, Train Acc: 0.9219, Test Acc: 0.8438
# Epoch: 279, Train Acc: 0.9219, Test Acc: 0.8438
# Epoch: 280, Train Acc: 0.9219, Test Acc: 0.8438
# Epoch: 281, Train Acc: 0.9201, Test Acc: 0.8438
# Epoch: 282, Train Acc: 0.9149, Test Acc: 0.8438
# Epoch: 283, Train Acc: 0.9219, Test Acc: 0.8438
# Epoch: 284, Train Acc: 0.9201, Test Acc: 0.8438
# Epoch: 285, Train Acc: 0.9201, Test Acc: 0.8438
# Epoch: 286, Train Acc: 0.9184, Test Acc: 0.8438
# Epoch: 287, Train Acc: 0.9149, Test Acc: 0.8438
# Epoch: 288, Train Acc: 0.9184, Test Acc: 0.8438
# Epoch: 289, Train Acc: 0.9184, Test Acc: 0.8438
# Epoch: 290, Train Acc: 0.9201, Test Acc: 0.8438
# Epoch: 291, Train Acc: 0.9219, Test Acc: 0.8438
# Epoch: 292, Train Acc: 0.9219, Test Acc: 0.8438
# Epoch: 293, Train Acc: 0.9236, Test Acc: 0.8438
# Epoch: 294, Train Acc: 0.9219, Test Acc: 0.8438
# Epoch: 295, Train Acc: 0.9219, Test Acc: 0.8438
# Epoch: 296, Train Acc: 0.9236, Test Acc: 0.8438
# Epoch: 297, Train Acc: 0.9236, Test Acc: 0.8438
# Epoch: 298, Train Acc: 0.9219, Test Acc: 0.8438
# Epoch: 299, Train Acc: 0.9219, Test Acc: 0.8438
# Epoch: 300, Train Acc: 0.9236, Test Acc: 0.8438
# Epoch: 301, Train Acc: 0.9253, Test Acc: 0.8438
# Epoch: 302, Train Acc: 0.9201, Test Acc: 0.8438
# Epoch: 303, Train Acc: 0.9201, Test Acc: 0.8438
# Epoch: 304, Train Acc: 0.9236, Test Acc: 0.8438
# Epoch: 305, Train Acc: 0.9236, Test Acc: 0.8438
# Epoch: 306, Train Acc: 0.9271, Test Acc: 0.8438
# Epoch: 307, Train Acc: 0.9253, Test Acc: 0.8438
# Epoch: 308, Train Acc: 0.9236, Test Acc: 0.8438
# Epoch: 309, Train Acc: 0.9288, Test Acc: 0.8438
# Epoch: 310, Train Acc: 0.9253, Test Acc: 0.8438
# Epoch: 311, Train Acc: 0.9219, Test Acc: 0.8438
# Epoch: 312, Train Acc: 0.9271, Test Acc: 0.8438
# Epoch: 313, Train Acc: 0.9288, Test Acc: 0.8438
# Epoch: 314, Train Acc: 0.9288, Test Acc: 0.8438
# Epoch: 315, Train Acc: 0.9288, Test Acc: 0.8438
# Epoch: 316, Train Acc: 0.9271, Test Acc: 0.8438
# Epoch: 317, Train Acc: 0.9253, Test Acc: 0.8438
# Epoch: 318, Train Acc: 0.9253, Test Acc: 0.8438
# Epoch: 319, Train Acc: 0.9288, Test Acc: 0.8438
# Epoch: 320, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 321, Train Acc: 0.9288, Test Acc: 0.8438
# Epoch: 322, Train Acc: 0.9271, Test Acc: 0.8438
# Epoch: 323, Train Acc: 0.9288, Test Acc: 0.8438
# Epoch: 324, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 325, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 326, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 327, Train Acc: 0.9271, Test Acc: 0.8438
# Epoch: 328, Train Acc: 0.9288, Test Acc: 0.8438
# Epoch: 329, Train Acc: 0.9288, Test Acc: 0.8438
# Epoch: 330, Train Acc: 0.9288, Test Acc: 0.8438
# Epoch: 331, Train Acc: 0.9288, Test Acc: 0.8438
# Epoch: 332, Train Acc: 0.9288, Test Acc: 0.8438
# Epoch: 333, Train Acc: 0.9253, Test Acc: 0.8438
# Epoch: 334, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 335, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 336, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 337, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 338, Train Acc: 0.9288, Test Acc: 0.8438
# Epoch: 339, Train Acc: 0.9288, Test Acc: 0.8438
# Epoch: 340, Train Acc: 0.9288, Test Acc: 0.8438
# Epoch: 341, Train Acc: 0.9271, Test Acc: 0.8438
# Epoch: 342, Train Acc: 0.9271, Test Acc: 0.8438
# Epoch: 343, Train Acc: 0.9271, Test Acc: 0.8438
# Epoch: 344, Train Acc: 0.9271, Test Acc: 0.8438
# Epoch: 345, Train Acc: 0.9271, Test Acc: 0.8438
# Epoch: 346, Train Acc: 0.9271, Test Acc: 0.8438
# Epoch: 347, Train Acc: 0.9271, Test Acc: 0.8438
# Epoch: 348, Train Acc: 0.9288, Test Acc: 0.8438
# Epoch: 349, Train Acc: 0.9288, Test Acc: 0.8438
# Epoch: 350, Train Acc: 0.9271, Test Acc: 0.8438
# Epoch: 351, Train Acc: 0.9288, Test Acc: 0.8594
# Epoch: 352, Train Acc: 0.9306, Test Acc: 0.8594
# Epoch: 353, Train Acc: 0.9288, Test Acc: 0.8438
# Epoch: 354, Train Acc: 0.9288, Test Acc: 0.8438
# Epoch: 355, Train Acc: 0.9288, Test Acc: 0.8438
# Epoch: 356, Train Acc: 0.9288, Test Acc: 0.8438
# Epoch: 357, Train Acc: 0.9288, Test Acc: 0.8438
# Epoch: 358, Train Acc: 0.9271, Test Acc: 0.8438
# Epoch: 359, Train Acc: 0.9253, Test Acc: 0.8438
# Epoch: 360, Train Acc: 0.9253, Test Acc: 0.8438
# Epoch: 361, Train Acc: 0.9271, Test Acc: 0.8438
# Epoch: 362, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 363, Train Acc: 0.9288, Test Acc: 0.8438
# Epoch: 364, Train Acc: 0.9323, Test Acc: 0.8594
# Epoch: 365, Train Acc: 0.9323, Test Acc: 0.8594
# Epoch: 366, Train Acc: 0.9323, Test Acc: 0.8594
# Epoch: 367, Train Acc: 0.9323, Test Acc: 0.8594
# Epoch: 368, Train Acc: 0.9271, Test Acc: 0.8594
# Epoch: 369, Train Acc: 0.9306, Test Acc: 0.8594
# Epoch: 370, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 371, Train Acc: 0.9288, Test Acc: 0.8438
# Epoch: 372, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 373, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 374, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 375, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 376, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 377, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 378, Train Acc: 0.9323, Test Acc: 0.8438
# Epoch: 379, Train Acc: 0.9271, Test Acc: 0.8438
# Epoch: 380, Train Acc: 0.9323, Test Acc: 0.8438
# Epoch: 381, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 382, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 383, Train Acc: 0.9323, Test Acc: 0.8438
# Epoch: 384, Train Acc: 0.9323, Test Acc: 0.8438
# Epoch: 385, Train Acc: 0.9340, Test Acc: 0.8594
# Epoch: 386, Train Acc: 0.9340, Test Acc: 0.8594
# Epoch: 387, Train Acc: 0.9306, Test Acc: 0.8594
# Epoch: 388, Train Acc: 0.9306, Test Acc: 0.8594
# Epoch: 389, Train Acc: 0.9306, Test Acc: 0.8594
# Epoch: 390, Train Acc: 0.9288, Test Acc: 0.8438
# Epoch: 391, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 392, Train Acc: 0.9340, Test Acc: 0.8438
# Epoch: 393, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 394, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 395, Train Acc: 0.9323, Test Acc: 0.8438
# Epoch: 396, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 397, Train Acc: 0.9323, Test Acc: 0.8438
# Epoch: 398, Train Acc: 0.9323, Test Acc: 0.8438
# Epoch: 399, Train Acc: 0.9323, Test Acc: 0.8438
# Epoch: 400, Train Acc: 0.9323, Test Acc: 0.8438
# Epoch: 401, Train Acc: 0.9323, Test Acc: 0.8438
# Epoch: 402, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 403, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 404, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 405, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 406, Train Acc: 0.9323, Test Acc: 0.8438
# Epoch: 407, Train Acc: 0.9288, Test Acc: 0.8438
# Epoch: 408, Train Acc: 0.9323, Test Acc: 0.8438
# Epoch: 409, Train Acc: 0.9340, Test Acc: 0.8438
# Epoch: 410, Train Acc: 0.9323, Test Acc: 0.8438
# Epoch: 411, Train Acc: 0.9323, Test Acc: 0.8438
# Epoch: 412, Train Acc: 0.9323, Test Acc: 0.8438
# Epoch: 413, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 414, Train Acc: 0.9323, Test Acc: 0.8438
# Epoch: 415, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 416, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 417, Train Acc: 0.9323, Test Acc: 0.8438
# Epoch: 418, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 419, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 420, Train Acc: 0.9323, Test Acc: 0.8438
# Epoch: 421, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 422, Train Acc: 0.9358, Test Acc: 0.8594
# Epoch: 423, Train Acc: 0.9340, Test Acc: 0.8594
# Epoch: 424, Train Acc: 0.9323, Test Acc: 0.8438
# Epoch: 425, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 426, Train Acc: 0.9323, Test Acc: 0.8438
# Epoch: 427, Train Acc: 0.9323, Test Acc: 0.8438
# Epoch: 428, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 429, Train Acc: 0.9323, Test Acc: 0.8438
# Epoch: 430, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 431, Train Acc: 0.9288, Test Acc: 0.8438
# Epoch: 432, Train Acc: 0.9323, Test Acc: 0.8438
# Epoch: 433, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 434, Train Acc: 0.9358, Test Acc: 0.8438
# Epoch: 435, Train Acc: 0.9323, Test Acc: 0.8438
# Epoch: 436, Train Acc: 0.9340, Test Acc: 0.8438
# Epoch: 437, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 438, Train Acc: 0.9375, Test Acc: 0.8594
# Epoch: 439, Train Acc: 0.9392, Test Acc: 0.8594
# Epoch: 440, Train Acc: 0.9323, Test Acc: 0.8594
# Epoch: 441, Train Acc: 0.9306, Test Acc: 0.8438
# Epoch: 442, Train Acc: 0.9340, Test Acc: 0.8750
# Epoch: 443, Train Acc: 0.9392, Test Acc: 0.8750
# Epoch: 444, Train Acc: 0.9340, Test Acc: 0.8438
# Epoch: 445, Train Acc: 0.9375, Test Acc: 0.8594
# Epoch: 446, Train Acc: 0.9375, Test Acc: 0.8438
# Epoch: 447, Train Acc: 0.9375, Test Acc: 0.8438
# Epoch: 448, Train Acc: 0.9410, Test Acc: 0.8594
# Epoch: 449, Train Acc: 0.9375, Test Acc: 0.8438
# Epoch: 450, Train Acc: 0.9340, Test Acc: 0.8438
# Epoch: 451, Train Acc: 0.9358, Test Acc: 0.8438
# Epoch: 452, Train Acc: 0.9410, Test Acc: 0.8594
# Epoch: 453, Train Acc: 0.9392, Test Acc: 0.8438
# Epoch: 454, Train Acc: 0.9410, Test Acc: 0.8438
# Epoch: 455, Train Acc: 0.9392, Test Acc: 0.8438
# Epoch: 456, Train Acc: 0.9392, Test Acc: 0.8438
# Epoch: 457, Train Acc: 0.9375, Test Acc: 0.8438
# Epoch: 458, Train Acc: 0.9392, Test Acc: 0.8594
# Epoch: 459, Train Acc: 0.9358, Test Acc: 0.8438
# Epoch: 460, Train Acc: 0.9410, Test Acc: 0.8438
# Epoch: 461, Train Acc: 0.9392, Test Acc: 0.8438
# Epoch: 462, Train Acc: 0.9392, Test Acc: 0.8438
# Epoch: 463, Train Acc: 0.9392, Test Acc: 0.8594
# Epoch: 464, Train Acc: 0.9392, Test Acc: 0.8438
# Epoch: 465, Train Acc: 0.9358, Test Acc: 0.8438
# Epoch: 466, Train Acc: 0.9410, Test Acc: 0.8594
# Epoch: 467, Train Acc: 0.9375, Test Acc: 0.8594
# Epoch: 468, Train Acc: 0.9375, Test Acc: 0.8438
# Epoch: 469, Train Acc: 0.9375, Test Acc: 0.8438
# Epoch: 470, Train Acc: 0.9392, Test Acc: 0.8438
# Epoch: 471, Train Acc: 0.9375, Test Acc: 0.8438
# Epoch: 472, Train Acc: 0.9410, Test Acc: 0.8438
# Epoch: 473, Train Acc: 0.9392, Test Acc: 0.8438
# Epoch: 474, Train Acc: 0.9392, Test Acc: 0.8438
# Epoch: 475, Train Acc: 0.9410, Test Acc: 0.8438
# Epoch: 476, Train Acc: 0.9410, Test Acc: 0.8594
# Epoch: 477, Train Acc: 0.9410, Test Acc: 0.8594
# Epoch: 478, Train Acc: 0.9427, Test Acc: 0.8594
# Epoch: 479, Train Acc: 0.9462, Test Acc: 0.8594
# Epoch: 480, Train Acc: 0.9410, Test Acc: 0.8438
# Epoch: 481, Train Acc: 0.9427, Test Acc: 0.8438
# Epoch: 482, Train Acc: 0.9444, Test Acc: 0.8438
# Epoch: 483, Train Acc: 0.9427, Test Acc: 0.8438
# Epoch: 484, Train Acc: 0.9444, Test Acc: 0.8438
# Epoch: 485, Train Acc: 0.9444, Test Acc: 0.8438
# Epoch: 486, Train Acc: 0.9427, Test Acc: 0.8438
# Epoch: 487, Train Acc: 0.9427, Test Acc: 0.8438
# Epoch: 488, Train Acc: 0.9444, Test Acc: 0.8438
# Epoch: 489, Train Acc: 0.9427, Test Acc: 0.8438
# Epoch: 490, Train Acc: 0.9444, Test Acc: 0.8438
# Epoch: 491, Train Acc: 0.9444, Test Acc: 0.8594
# Epoch: 492, Train Acc: 0.9427, Test Acc: 0.8594
# Epoch: 493, Train Acc: 0.9427, Test Acc: 0.8438
# Epoch: 494, Train Acc: 0.9462, Test Acc: 0.8438
# Epoch: 495, Train Acc: 0.9479, Test Acc: 0.8438
# Epoch: 496, Train Acc: 0.9462, Test Acc: 0.8438
# Epoch: 497, Train Acc: 0.9427, Test Acc: 0.8438
# Epoch: 498, Train Acc: 0.9427, Test Acc: 0.8594
# Epoch: 499, Train Acc: 0.9444, Test Acc: 0.8594
# Epoch: 500, Train Acc: 0.9462, Test Acc: 0.8438
# Epoch: 501, Train Acc: 0.9462, Test Acc: 0.8594
# Epoch: 502, Train Acc: 0.9444, Test Acc: 0.8438
# Epoch: 503, Train Acc: 0.9444, Test Acc: 0.8438
# Epoch: 504, Train Acc: 0.9479, Test Acc: 0.8438
# Epoch: 505, Train Acc: 0.9497, Test Acc: 0.8594
# Epoch: 506, Train Acc: 0.9479, Test Acc: 0.8594
# Epoch: 507, Train Acc: 0.9444, Test Acc: 0.8438
# Epoch: 508, Train Acc: 0.9427, Test Acc: 0.8438
# Epoch: 509, Train Acc: 0.9427, Test Acc: 0.8594
# Epoch: 510, Train Acc: 0.9444, Test Acc: 0.8438
# Epoch: 511, Train Acc: 0.9462, Test Acc: 0.8438
# Epoch: 512, Train Acc: 0.9479, Test Acc: 0.8438
# Epoch: 513, Train Acc: 0.9479, Test Acc: 0.8438
# Epoch: 514, Train Acc: 0.9444, Test Acc: 0.8438
# Epoch: 515, Train Acc: 0.9479, Test Acc: 0.8594
# Epoch: 516, Train Acc: 0.9444, Test Acc: 0.8438
# Epoch: 517, Train Acc: 0.9444, Test Acc: 0.8438
# Epoch: 518, Train Acc: 0.9479, Test Acc: 0.8594
# Epoch: 519, Train Acc: 0.9462, Test Acc: 0.8594
# Epoch: 520, Train Acc: 0.9497, Test Acc: 0.8594
# Epoch: 521, Train Acc: 0.9497, Test Acc: 0.8594
# Epoch: 522, Train Acc: 0.9514, Test Acc: 0.8594
# Epoch: 523, Train Acc: 0.9444, Test Acc: 0.8594
# Epoch: 524, Train Acc: 0.9444, Test Acc: 0.8594
# Epoch: 525, Train Acc: 0.9497, Test Acc: 0.8438
# Epoch: 526, Train Acc: 0.9479, Test Acc: 0.8594
# Epoch: 527, Train Acc: 0.9479, Test Acc: 0.8438
# Epoch: 528, Train Acc: 0.9462, Test Acc: 0.8594
# Epoch: 529, Train Acc: 0.9479, Test Acc: 0.8594
# Epoch: 530, Train Acc: 0.9462, Test Acc: 0.8594
# Epoch: 531, Train Acc: 0.9462, Test Acc: 0.8438
# Epoch: 532, Train Acc: 0.9497, Test Acc: 0.8594
# Epoch: 533, Train Acc: 0.9531, Test Acc: 0.8438
# Epoch: 534, Train Acc: 0.9514, Test Acc: 0.8594
# Epoch: 535, Train Acc: 0.9514, Test Acc: 0.8594
# Epoch: 536, Train Acc: 0.9462, Test Acc: 0.8594
# Epoch: 537, Train Acc: 0.9462, Test Acc: 0.8594
# Epoch: 538, Train Acc: 0.9444, Test Acc: 0.8594
# Epoch: 539, Train Acc: 0.9444, Test Acc: 0.8594
# Epoch: 540, Train Acc: 0.9497, Test Acc: 0.8594
# Epoch: 541, Train Acc: 0.9479, Test Acc: 0.8594
# Epoch: 542, Train Acc: 0.9514, Test Acc: 0.8594
# Epoch: 543, Train Acc: 0.9497, Test Acc: 0.8594
# Epoch: 544, Train Acc: 0.9479, Test Acc: 0.8594
# Epoch: 545, Train Acc: 0.9531, Test Acc: 0.8594
# Epoch: 546, Train Acc: 0.9531, Test Acc: 0.8594
# Epoch: 547, Train Acc: 0.9497, Test Acc: 0.8594
# Epoch: 548, Train Acc: 0.9479, Test Acc: 0.8594
# Epoch: 549, Train Acc: 0.9514, Test Acc: 0.8594
# Epoch: 550, Train Acc: 0.9497, Test Acc: 0.8594
# Epoch: 551, Train Acc: 0.9497, Test Acc: 0.8594
# Epoch: 552, Train Acc: 0.9479, Test Acc: 0.8594
# Epoch: 553, Train Acc: 0.9479, Test Acc: 0.8594
# Epoch: 554, Train Acc: 0.9462, Test Acc: 0.8594
# Epoch: 555, Train Acc: 0.9479, Test Acc: 0.8594
# Epoch: 556, Train Acc: 0.9479, Test Acc: 0.8594
# Epoch: 557, Train Acc: 0.9462, Test Acc: 0.8594
# Epoch: 558, Train Acc: 0.9497, Test Acc: 0.8594
# Epoch: 559, Train Acc: 0.9514, Test Acc: 0.8594
# Epoch: 560, Train Acc: 0.9497, Test Acc: 0.8594
# Epoch: 561, Train Acc: 0.9497, Test Acc: 0.8594
# Epoch: 562, Train Acc: 0.9479, Test Acc: 0.8594
# Epoch: 563, Train Acc: 0.9514, Test Acc: 0.8594
# Epoch: 564, Train Acc: 0.9514, Test Acc: 0.8594
# Epoch: 565, Train Acc: 0.9514, Test Acc: 0.8594
# Epoch: 566, Train Acc: 0.9549, Test Acc: 0.8594
# Epoch: 567, Train Acc: 0.9531, Test Acc: 0.8594
# Epoch: 568, Train Acc: 0.9531, Test Acc: 0.8594
# Epoch: 569, Train Acc: 0.9514, Test Acc: 0.8594
# Epoch: 570, Train Acc: 0.9497, Test Acc: 0.8594
# Epoch: 571, Train Acc: 0.9497, Test Acc: 0.8594
# Epoch: 572, Train Acc: 0.9514, Test Acc: 0.8594
# Epoch: 573, Train Acc: 0.9514, Test Acc: 0.8594
# Epoch: 574, Train Acc: 0.9531, Test Acc: 0.8594
# Epoch: 575, Train Acc: 0.9514, Test Acc: 0.8594
# Epoch: 576, Train Acc: 0.9497, Test Acc: 0.8594
# Epoch: 577, Train Acc: 0.9497, Test Acc: 0.8594
# Epoch: 578, Train Acc: 0.9514, Test Acc: 0.8594
# Epoch: 579, Train Acc: 0.9479, Test Acc: 0.8594
# Epoch: 580, Train Acc: 0.9497, Test Acc: 0.8594
# Epoch: 581, Train Acc: 0.9514, Test Acc: 0.8594
# Epoch: 582, Train Acc: 0.9549, Test Acc: 0.8594
# Epoch: 583, Train Acc: 0.9566, Test Acc: 0.8594
# Epoch: 584, Train Acc: 0.9566, Test Acc: 0.8594
# Epoch: 585, Train Acc: 0.9566, Test Acc: 0.8594
# Epoch: 586, Train Acc: 0.9583, Test Acc: 0.8594
# Epoch: 587, Train Acc: 0.9566, Test Acc: 0.8594
# Epoch: 588, Train Acc: 0.9566, Test Acc: 0.8594
# Epoch: 589, Train Acc: 0.9514, Test Acc: 0.8594
# Epoch: 590, Train Acc: 0.9531, Test Acc: 0.8594
# Epoch: 591, Train Acc: 0.9514, Test Acc: 0.8594
# Epoch: 592, Train Acc: 0.9531, Test Acc: 0.8594
# Epoch: 593, Train Acc: 0.9531, Test Acc: 0.8594
# Epoch: 594, Train Acc: 0.9531, Test Acc: 0.8594
# Epoch: 595, Train Acc: 0.9549, Test Acc: 0.8594
# Epoch: 596, Train Acc: 0.9566, Test Acc: 0.8594
# Epoch: 597, Train Acc: 0.9549, Test Acc: 0.8594
# Epoch: 598, Train Acc: 0.9549, Test Acc: 0.8594
# Epoch: 599, Train Acc: 0.9549, Test Acc: 0.8594
# Epoch: 600, Train Acc: 0.9549, Test Acc: 0.8594
# Epoch: 601, Train Acc: 0.9514, Test Acc: 0.8594
# Epoch: 602, Train Acc: 0.9531, Test Acc: 0.8594
# Epoch: 603, Train Acc: 0.9601, Test Acc: 0.8594
# Epoch: 604, Train Acc: 0.9566, Test Acc: 0.8594
# Epoch: 605, Train Acc: 0.9549, Test Acc: 0.8594
# Epoch: 606, Train Acc: 0.9566, Test Acc: 0.8594
# Epoch: 607, Train Acc: 0.9566, Test Acc: 0.8594
# Epoch: 608, Train Acc: 0.9566, Test Acc: 0.8594
# Epoch: 609, Train Acc: 0.9566, Test Acc: 0.8594
# Epoch: 610, Train Acc: 0.9583, Test Acc: 0.8594
# Epoch: 611, Train Acc: 0.9566, Test Acc: 0.8594
# Epoch: 612, Train Acc: 0.9549, Test Acc: 0.8594
# Epoch: 613, Train Acc: 0.9566, Test Acc: 0.8594
# Epoch: 614, Train Acc: 0.9549, Test Acc: 0.8594
# Epoch: 615, Train Acc: 0.9531, Test Acc: 0.8594
# Epoch: 616, Train Acc: 0.9566, Test Acc: 0.8594
# Epoch: 617, Train Acc: 0.9583, Test Acc: 0.8594
# Epoch: 618, Train Acc: 0.9583, Test Acc: 0.8594
# Epoch: 619, Train Acc: 0.9601, Test Acc: 0.8594
# Epoch: 620, Train Acc: 0.9583, Test Acc: 0.8594
# Epoch: 621, Train Acc: 0.9549, Test Acc: 0.8594
# Epoch: 622, Train Acc: 0.9566, Test Acc: 0.8594
# Epoch: 623, Train Acc: 0.9566, Test Acc: 0.8594
# Epoch: 624, Train Acc: 0.9566, Test Acc: 0.8594
# Epoch: 625, Train Acc: 0.9601, Test Acc: 0.8594
# Epoch: 626, Train Acc: 0.9601, Test Acc: 0.8594
# Epoch: 627, Train Acc: 0.9601, Test Acc: 0.8594
# Epoch: 628, Train Acc: 0.9583, Test Acc: 0.8594
# Epoch: 629, Train Acc: 0.9566, Test Acc: 0.8594
# Epoch: 630, Train Acc: 0.9583, Test Acc: 0.8594
# Epoch: 631, Train Acc: 0.9583, Test Acc: 0.8594
# Epoch: 632, Train Acc: 0.9583, Test Acc: 0.8594
# Epoch: 633, Train Acc: 0.9583, Test Acc: 0.8594
# Epoch: 634, Train Acc: 0.9618, Test Acc: 0.8594
# Epoch: 635, Train Acc: 0.9583, Test Acc: 0.8594
# Epoch: 636, Train Acc: 0.9601, Test Acc: 0.8594
# Epoch: 637, Train Acc: 0.9618, Test Acc: 0.8594
# Epoch: 638, Train Acc: 0.9601, Test Acc: 0.8594
# Epoch: 639, Train Acc: 0.9583, Test Acc: 0.8594
# Epoch: 640, Train Acc: 0.9583, Test Acc: 0.8594
# Epoch: 641, Train Acc: 0.9549, Test Acc: 0.8594
# Epoch: 642, Train Acc: 0.9601, Test Acc: 0.8594
# Epoch: 643, Train Acc: 0.9549, Test Acc: 0.8594
# Epoch: 644, Train Acc: 0.9601, Test Acc: 0.8594
# Epoch: 645, Train Acc: 0.9618, Test Acc: 0.8594
# Epoch: 646, Train Acc: 0.9566, Test Acc: 0.8594
# Epoch: 647, Train Acc: 0.9566, Test Acc: 0.8594
# Epoch: 648, Train Acc: 0.9583, Test Acc: 0.8594
# Epoch: 649, Train Acc: 0.9566, Test Acc: 0.8594
# Epoch: 650, Train Acc: 0.9601, Test Acc: 0.8594
# Epoch: 651, Train Acc: 0.9583, Test Acc: 0.8594
# Epoch: 652, Train Acc: 0.9601, Test Acc: 0.8594
# Epoch: 653, Train Acc: 0.9583, Test Acc: 0.8594
# Epoch: 654, Train Acc: 0.9566, Test Acc: 0.8594
# Epoch: 655, Train Acc: 0.9601, Test Acc: 0.8594
# Epoch: 656, Train Acc: 0.9601, Test Acc: 0.8594
# Epoch: 657, Train Acc: 0.9618, Test Acc: 0.8594
# Epoch: 658, Train Acc: 0.9601, Test Acc: 0.8594
# Epoch: 659, Train Acc: 0.9618, Test Acc: 0.8594
# Epoch: 660, Train Acc: 0.9566, Test Acc: 0.8594
# Epoch: 661, Train Acc: 0.9601, Test Acc: 0.8594
# Epoch: 662, Train Acc: 0.9601, Test Acc: 0.8594
# Epoch: 663, Train Acc: 0.9583, Test Acc: 0.8594
# Epoch: 664, Train Acc: 0.9583, Test Acc: 0.8594
# Epoch: 665, Train Acc: 0.9601, Test Acc: 0.8594
# Epoch: 666, Train Acc: 0.9601, Test Acc: 0.8594
# Epoch: 667, Train Acc: 0.9601, Test Acc: 0.8594
# Epoch: 668, Train Acc: 0.9566, Test Acc: 0.8594
# Epoch: 669, Train Acc: 0.9566, Test Acc: 0.8594
# Epoch: 670, Train Acc: 0.9601, Test Acc: 0.8594
# Epoch: 671, Train Acc: 0.9583, Test Acc: 0.8594
# Epoch: 672, Train Acc: 0.9618, Test Acc: 0.8594
# Epoch: 673, Train Acc: 0.9601, Test Acc: 0.8594
# Epoch: 674, Train Acc: 0.9566, Test Acc: 0.8594
# Epoch: 675, Train Acc: 0.9549, Test Acc: 0.8594
# Epoch: 676, Train Acc: 0.9583, Test Acc: 0.8594
# Epoch: 677, Train Acc: 0.9601, Test Acc: 0.8594
# Epoch: 678, Train Acc: 0.9601, Test Acc: 0.8594
# Epoch: 679, Train Acc: 0.9601, Test Acc: 0.8594
# Epoch: 680, Train Acc: 0.9601, Test Acc: 0.8594
# Epoch: 681, Train Acc: 0.9601, Test Acc: 0.8594
# Epoch: 682, Train Acc: 0.9583, Test Acc: 0.8594
# Epoch: 683, Train Acc: 0.9601, Test Acc: 0.8594
# Epoch: 684, Train Acc: 0.9618, Test Acc: 0.8594
# Epoch: 685, Train Acc: 0.9601, Test Acc: 0.8594
# Epoch: 686, Train Acc: 0.9549, Test Acc: 0.8594
# Epoch: 687, Train Acc: 0.9635, Test Acc: 0.8594
# Epoch: 688, Train Acc: 0.9549, Test Acc: 0.8594
# Epoch: 689, Train Acc: 0.9618, Test Acc: 0.8594
# Epoch: 690, Train Acc: 0.9601, Test Acc: 0.8594
# Epoch: 691, Train Acc: 0.9583, Test Acc: 0.8594
# Epoch: 692, Train Acc: 0.9601, Test Acc: 0.8594
# Epoch: 693, Train Acc: 0.9601, Test Acc: 0.8594
# Epoch: 694, Train Acc: 0.9583, Test Acc: 0.8594
# Epoch: 695, Train Acc: 0.9583, Test Acc: 0.8594
# Epoch: 696, Train Acc: 0.9601, Test Acc: 0.8594
# Epoch: 697, Train Acc: 0.9583, Test Acc: 0.8594
# Epoch: 698, Train Acc: 0.9618, Test Acc: 0.8594
# Epoch: 699, Train Acc: 0.9618, Test Acc: 0.8594

# %%
for data in test_loader:
    out = model(data.x, data.edge_index, data.batch)
    lab = data.y

# %%
out.shape
# Out:
# torch.Size([64, 2])

# %%
lab.shape
# Out:
# torch.Size([64])

# %%
skplt.metrics.plot_roc(lab, out.detach().numpy())
# Out:
# <AxesSubplot:title={'center':'ROC Curves'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>
